# %% [markdown]
# ## 0. Create Spark session

# %%
import os
from pyspark.sql import SparkSession
from pyspark import SparkConf
from pyspark import SparkContext

os.environ['PYSPARK_SUBMIT_ARGS'] = (
    '--packages org.apache.hadoop:hadoop-aws:3.2.0,org.apache.hadoop:hadoop-common:3.2.0,io.trino:trino-jdbc:422 '
    'pyspark-shell'
)
os.environ['S3_ENDPOINT'] = "http://minio:9000"
os.environ['AWS_ACCESS_KEY_ID'] = "minio"
os.environ['AWS_SECRET_ACCESS_KEY'] = "minio123"

spark = (
    SparkSession.builder
    .appName("spark-read-minio")
    .config("spark.hadoop.fs.s3a.access.key", os.getenv("AWS_ACCESS_KEY_ID"))
    .config("spark.hadoop.fs.s3a.secret.key", os.getenv("AWS_SECRET_ACCESS_KEY"))
    .config("spark.hadoop.fs.s3a.endpoint", os.getenv("S3_ENDPOINT"))
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.hadoop.fs.s3a.attempts.maximum", "1")
    .config("spark.hadoop.fs.s3a.connection.establish.timeout", "5000")
    .config("spark.hadoop.fs.s3a.connection.timeout", "10000")
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/spark-3.1.2-bin-hadoop3.2/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# :: loading settings :: url = jar:file:/usr/local/spark-3.1.2-bin-hadoop3.2/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/jovyan/.ivy2/cache
# The jars for the packages stored in: /home/jovyan/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# io.trino#trino-jdbc added as a dependency
# ...

# %% [markdown]
# ## 1. Extract from object storage

# %%
from pyspark.sql import functions as F

silver_path = "s3a://velib/silver/velib-disponibilite-en-temps-reel"
df_silver = spark.read.parquet(silver_path)

# Date de coupure + filtre
date_coupure = "2024-10-31"
df_silver = df_silver.filter(F.col("duedate") >= date_coupure)

# Vérifications
print("Schema:")
df_silver.printSchema()
print("\nSample data:")
df_silver.show(5, truncate=False)
print("\nTotal records:", df_silver.count())
# Out:
# 24/11/04 13:59:15 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Schema:
# root
#  |-- capacity: long (nullable = true)
#  |-- duedate: string (nullable = true)
#  |-- ebike: long (nullable = true)
#  |-- is_installed: string (nullable = true)
#  |-- is_renting: string (nullable = true)
#  |-- is_returning: string (nullable = true)
#  |-- mechanical: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- nom_arrondissement_communes: string (nullable = true)
#  |-- numbikesavailable: long (nullable = true)
#  |-- numdocksavailable: long (nullable = true)
#  |-- stationcode: string (nullable = true)
#  |-- fill_ratio: double (nullable = true)
#  |-- part_minute: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- part_day: date (nullable = true)
#
#
# Sample data:
# ...

# %% [markdown]
# ## 2. Transform

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

df_silver = df_silver.filter(F.col("stationcode").isNotNull())
df_silver = df_silver.withColumn("timestamp", F.to_timestamp("duedate"))
df_silver = df_silver.withColumn("hour", F.date_format("timestamp", "yyyy-MM-dd HH:00:00"))
window_station = Window.partitionBy("stationcode").orderBy("timestamp")

# Calcul du turnover rate (départ/arrivé): compte +1 pour chaque arrivée et +1 pour chaque départ
df_turnover = df_silver.withColumn(
    "arrivals", F.when(F.col("numbikesavailable") > F.lag("numbikesavailable", 1).over(window_station), 
                      F.col("numbikesavailable") - F.lag("numbikesavailable", 1).over(window_station)).otherwise(0)
)

df_turnover = df_turnover.withColumn(
    "departures", F.when(F.col("numbikesavailable") < F.lag("numbikesavailable", 1).over(window_station), 
                         F.lag("numbikesavailable", 1).over(window_station) - F.col("numbikesavailable")).otherwise(0)
)

# Turnover rate total : somme des arrivées et des départs
df_turnover = df_turnover.withColumn("date", F.substring(F.col("duedate"), 1, 10)).groupBy("stationcode", "hour", "date").agg(
    F.sum("arrivals").alias("total_arrivals"),
    F.sum("departures").alias("total_departures"),
    (F.sum("arrivals") + F.sum("departures")).alias("total_turnover_rate"),
    F.first("name").alias("station_name"),     
    F.first("capacity").alias("station_capacity"),
    F.last("numbikesavailable", ignorenulls=True).alias("numbikesavailable")
)

# Affichage du résultat
df_turnover.select("stationcode", "hour", "date", "total_arrivals", "total_departures", "total_turnover_rate", "station_capacity", "station_name").limit(30).toPandas()
# Out:
#    stationcode                 hour        date  total_arrivals  \
# 0        26005  2024-10-31 07:00:00  2024-10-31              11
# 1        26005  2024-10-31 09:00:00  2024-10-31              29
# 2        26005  2024-10-31 11:00:00  2024-10-31               0
# 3        26005  2024-10-31 12:00:00  2024-10-31               8
# 4        26005  2024-10-31 13:00:00  2024-10-31               7
# 5        30002  2024-10-31 07:00:00  2024-10-31               0
# 6        30002  2024-10-31 09:00:00  2024-10-31              16
# 7        30002  2024-10-31 11:00:00  2024-10-31               0
# 8        30002  2024-10-31 12:00:00  2024-10-31               2
# 9        30002  2024-10-31 13:00:00  2024-10-31               7
# 10       35004  2024-10-31 07:00:00  2024-10-31               6
# 11       35004  2024-10-31 09:00:00  2024-10-31               4
# 12       35004  2024-10-31 10:00:00  2024-10-31               5
# 13       35004  2024-10-31 11:00:00  2024-10-31               0
# ...

# %%
# Calcul des statistiques sur l'ensemble des stations par plage de temps
stats_global = df_silver.withColumn("date", F.substring(F.col("duedate"), 1, 10)).groupBy("hour").agg(
    F.avg("numbikesavailable").alias("mean_available"),
    F.expr("percentile(numbikesavailable, 0.5)").alias("median_available"),
    F.min("numbikesavailable").alias("min_available"),
    F.max("numbikesavailable").alias("max_available")
)


# Affichage
print("Statistiques globales par plage de temps :")
stats_global.limit(30).toPandas()  #.show(truncate=False)
# Out:
# Statistiques globales par plage de temps :
#                   hour  mean_available  median_available  min_available  \
# 0  2024-10-31 10:00:00       16.029145              13.0              0
# 1  2024-10-31 07:00:00       11.571198               9.0              0
# 2  2024-10-31 11:00:00       11.967318               9.0              0
# 3  2024-10-31 09:00:00       10.783099               7.0              0
# 4  2024-10-31 13:00:00       12.174249               8.0              0
# 5  2024-10-31 12:00:00       12.064662               9.0              0
# 6  2024-10-31 06:00:00        0.322581               0.0              0
# 7  2024-10-31 08:00:00        3.662614               2.0              0
#
#    max_available
# 0             66
# 1             65
# 2             65
# 3             65
# 4             66
# 5             66
# 6              1
# 7             20

# %%
# Calcul des statistiques par station par heure
stats_station = (
    df_silver
    .withColumn("date", F.substring(F.col("duedate"), 1, 10))
    .groupBy("stationcode", "hour")
    .agg(
        F.avg("numbikesavailable").alias("mean_available"),
        F.expr("percentile_approx(numbikesavailable, 0.5)").alias("median_available"),  # Correction ici
        F.min("numbikesavailable").alias("min_available"),
        F.max("numbikesavailable").alias("max_available"),
        F.first("name").alias("name")
    )
)

# Affichage des statistiques par station
print("Statistiques par station par heure :")
stats_station.limit(20).toPandas()
# Out:
# Statistiques par station par heure :
#    stationcode                 hour  mean_available  median_available  \
# 0        10113  2024-10-31 10:00:00        2.505882                 3
# 1         1016  2024-10-31 10:00:00       18.576471                19
# 2        11004  2024-10-31 12:00:00       26.911111                24
# 3        11014  2024-10-31 11:00:00       17.000000                17
# 4        11037  2024-10-31 11:00:00       25.000000                25
# 5        11112  2024-10-31 11:00:00        5.000000                 5
# 6        12027  2024-10-31 09:00:00        8.863636                 9
# 7        12040  2024-10-31 13:00:00       16.700000                17
# 8        12123  2024-10-31 09:00:00       23.361702                24
# 9        13103  2024-10-31 09:00:00       21.000000                21
# 10       14132  2024-10-31 11:00:00        3.000000                 3
# 11       15011  2024-10-31 12:00:00       32.622222                31
# ...

# %% [markdown]
# ## 3. Load into object storage

# %%
os.environ['S3_OUTPUT_PATH'] = "s3a://velib/gold/velib-disponibilite-en-temps-reel"

df_turnover.printSchema()

# Création de hour_start selon le type de hour
if df_turnover.schema["hour"].dataType.simpleString() == "struct":
    df_turnover = df_turnover.withColumn("hour_start", F.col("hour.start"))
else:
    df_turnover = df_turnover.withColumn("hour_start", F.col("hour"))  

df_turnover = df_turnover.withColumn("hour_start", F.to_timestamp(F.col("hour_start")))
stats_global = stats_global.withColumn("hour_start", F.col("hour.start") if df_turnover.schema["hour"].dataType.simpleString() == "struct" else F.col("hour"))

df_turnover = df_turnover.drop("hour")
stats_global = stats_global.drop("hour")
stats_station = stats_station.drop("hour")

# Ecriture des df dans minio
# turnover
(
    df_turnover.write
    .partitionBy("hour_start")  
    .format("parquet")
    .mode("overwrite")
    .save(f"{os.getenv('S3_OUTPUT_PATH')}/turnover")
)

# statistiques globales
(
    stats_global.write
    .partitionBy("hour_start")
    .format("parquet")
    .mode("overwrite")
    .save(f"{os.getenv('S3_OUTPUT_PATH')}/stats_global")
)

#statistiques par stations
(
    stats_station.write
    .partitionBy("name")
    .format("parquet")
    .mode("overwrite")
    .save(f"{os.getenv('S3_OUTPUT_PATH')}/stats_station")
)

df_parquet = spark.read.parquet(f"{os.getenv('S3_OUTPUT_PATH')}/stats_station")
df_parquet.printSchema()
# Out:
# root
#  |-- stationcode: string (nullable = true)
#  |-- hour: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- total_arrivals: long (nullable = true)
#  |-- total_departures: long (nullable = true)
#  |-- total_turnover_rate: long (nullable = true)
#  |-- station_name: string (nullable = true)
#  |-- station_capacity: long (nullable = true)
#  |-- numbikesavailable: long (nullable = true)
# 24/11/04 13:59:46 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/11/04 13:59:46 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/11/04 13:59:46 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# ...

# %% [markdown]
# ## 4. Update hive metastore

# %%
# !pip install trino

# %%
import trino
from pyspark.sql import functions as F
from pyspark.sql.window import Window
 
# Connection
def get_trino_connection():
    host, port, user = 'trino-coordinator', 8080, 'trino'
    return trino.dbapi.connect(host=host, port=port, user=user)
 
# Schémas des tables
velib_turnover = f"""
    date VARCHAR,
    total_arrivals BIGINT,
    total_departures BIGINT,
    total_turnover_rate BIGINT,
    station_capacity BIGINT,
    station_name VARCHAR,
    numbikesavailable BIGINT,
    hour_start TIMESTAMP
"""

velib_stats = f"""
    mean_available DOUBLE,
    median_available DOUBLE,
    min_available BIGINT,
    max_available BIGINT,
    hour_start TIMESTAMP
"""
    
velib_stats_station = f"""
    stationcode VARCHAR,
    mean_available DOUBLE,
    median_available BIGINT,
    min_available BIGINT,
    max_available BIGINT,
    name VARCHAR
"""

 
# Création de la table Trino
def create_trino_table(catalog, schema_name, table, schema, partitioned_by, external_location):
    conn = get_trino_connection()
    cur = conn.cursor()
    queries = [
        f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema_name} WITH (location = '{external_location}')",
        f"DROP TABLE IF EXISTS {catalog}.{schema_name}.{table}",
        f"""
        CREATE TABLE IF NOT EXISTS {catalog}.{schema_name}.{table} (
        {schema}
        )
        WITH (
            format = 'PARQUET',
            partitioned_by = ARRAY['{partitioned_by}'],
            external_location = '{external_location}'
        )
        """,
        f"CALL {catalog}.system.sync_partition_metadata('{schema_name}', '{table}', 'ADD')",
        f"SELECT * FROM {catalog}.{schema_name}.{table} LIMIT 5"
    ]
    for query in queries:
        try:
            cur.execute(query)
            if query.startswith("SELECT"):
                results = cur.fetchall()
                for row in results:
                    print(row)
            else:
                print(f"Executed: {query}")
        except Exception as e:
            print(f"Error executing query: {query}. Error: {e}")
    cur.close()
    conn.close()

output_path = 's3a://velib/gold/velib-disponibilite-en-temps-reel'
 
# Appel de la fonction avec les schémas
create_trino_table('minio', 'velib_gold_turnover', 'velib_disponibilite_turnover', velib_turnover, 'hour_start',  f"{output_path}/turnover")
create_trino_table('minio', 'velib_gold_stats', 'velib_disponibilite_stats', velib_stats, 'hour_start',  f"{output_path}/stats_global")
create_trino_table('minio', 'velib_gold_stats_station', 'velib_disponibilite_stats_station', velib_stats_station, 'name', f"{output_path}/stats_station")
# Out:
# Executed: CREATE SCHEMA IF NOT EXISTS minio.velib_gold_turnover WITH (location = 's3a://velib/gold/velib-disponibilite-en-temps-reel/turnover')
# Executed: DROP TABLE IF EXISTS minio.velib_gold_turnover.velib_disponibilite_turnover
# Executed:
#         CREATE TABLE IF NOT EXISTS minio.velib_gold_turnover.velib_disponibilite_turnover (
#
#     date VARCHAR,
#     total_arrivals BIGINT,
#     total_departures BIGINT,
#     total_turnover_rate BIGINT,
#     station_capacity BIGINT,
#     station_name VARCHAR,
#     numbikesavailable BIGINT,
#     hour_start TIMESTAMP
#
#         )
#         WITH (
#             format = 'PARQUET',
#             partitioned_by = ARRAY['hour_start'],
#             external_location = 's3a://velib/gold/velib-disponibilite-en-temps-reel/turnover'
#         )
#
# Executed: CALL minio.system.sync_partition_metadata('velib_gold_turnover', 'velib_disponibilite_turnover', 'ADD')
# ...
